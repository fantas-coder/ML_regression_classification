# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# Этот ноутбук содержит анализ данных.
# Датасет: `data_ml_v3-06.csv`.
# Цель:
# - изучить данные;
# - описать характеристики данных;
# - подготовить выводы для дальнейшей работы;

# %% [markdown]
# ## Шаг 0: Импортирование библиотек
#
# Импортируем библиотеки для работы с данными и визуализации
#
# - `pandas`: работа с DataFrame;
# - `numpy`: числовые операции;
# - `matplotlib` и `seaborn`: визуализация;

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import xlim

# Настройка стиля графиков
sns.set_style('whitegrid')

# %% [markdown]
# ## Шаг 1: Загрузка данных
#
# Загружаем датасет из папки `data`. Датасет содержит две колонки: `x` (признак) и `y` (целевая переменная)

# %%
df = pd.read_csv('../../data/data_ml_v3-06.csv')
df.head(10)
# Out:
#          x         y
# 0 -0.60604 -1.179300
# 1 -0.35888 -2.347900
# 2 -2.05920  1.811500
# 3 -1.04380  1.678300
# 4 -1.11560 -0.018185
# 5  2.36700 -0.479590
# 6 -1.51790  3.054500
# 7 -1.13590 -2.329200
# 8 -0.54679 -1.309700
# 9  1.24810  3.593100

# %% [markdown]
# ## Шаг 2: Описание данных
#
# Выводим информацию о данных:
# - **Объём выборки**: Количество строк и столбцов;
# - **Число признаков**: Колонка `x` (1 признак);
# - **Типы данных и пропуски**: Проверяем, всё ли числовое и есть ли NaN;
# - **Статистика**: Среднее, мин/макс, квартили для `x` и `y`;

# %%
# Общая информация
print("Объём выборки (строк, столбцов):", df.shape)
print()

print(f"Число признаков: {len(df.columns) - 1}: {[x for x in df.columns[:len(df.columns) - 1]]}")
print()

# Типы данных и пропуски
print("Информация о данных:")
df.info()
print()

# Пропуски
print("Пропуски:")
print(df.isnull().sum())
print()

# Статистическая сводка
print("Статистическая сводка:")
print(df.describe())
# Out:
# Объём выборки (строк, столбцов): (300, 2)
#
# Число признаков: 1: ['x']
#
# Информация о данных:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       300 non-null    float64
#  1   y       300 non-null    float64
# dtypes: float64(2)
# memory usage: 4.8 KB
#
# Пропуски:
# x    0
# y    0
# dtype: int64
#
# Статистическая сводка:
#                 x           y
# count  300.000000  300.000000
# mean     0.067339    1.950503
# std      1.726230    2.466536
# min     -2.991900   -4.743500
# 25%     -1.399675    0.307813
# 50%      0.000024    1.920250
# 75%      1.598750    3.524375
# max      2.947200    8.929800

# %% [markdown]
# ## Шаг 3: Визуализация распределений Scatter plot
#
# Scatter plot показывает зависимость `y` от `x`. Для регрессии идеально, если точки расположены визуально на одной кривой.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['x'], y=df['y'])
plt.title("Зависимость y от x")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ## Шаг 4: Выводы
#
# На основе анализа данных можно сделать следующие выводы:
# - **Объём выборки**: `300` строк, `2` столбца];
# - **Число признаков**: `1` (`x`);
# - **Целевая переменная**: `y`- непрерывная, подходит для регрессии;
# - **Пропуски**: `нет пропусков`;

# %% [markdown]
# ## Шаг 5. Сохранение предобработанной базы данных.

# %%
df.to_csv('../data/data_ml_v3_cleaned.csv', index=False)
print("Данные сохранены в 'data_ml_v3_cleaned.csv'")
# Out:
# Данные сохранены в 'data_ml_cleaned.csv'
